# %%
#pip install tensorflow
#pip install keras

# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta, date, timezone

import matplotlib.pyplot as plt
# %matplotlib inline

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# %%
# загрузим исходные данные о покупках
data = pd.read_csv('train.csv', sep=';', index_col='date', parse_dates=['date'], dayfirst=True)
data
# Out:
#             region        oktmo        okato   pasta legumes   bread  flour  \
# date
# 2021-03-31      72  71000000000  71000000000   86,36  108,63    75,1  34,06
# 2021-03-31      75  76000000000  76000000000   83,48  123,53   73,87  42,34
# 2021-03-31      74  75000000000  75000000000   75,59  103,61   81,43  33,27
# 2021-03-31      73  73000000000  73000000000   73,77   87,81   76,34  32,33
# 2021-03-31      65  64000000000  64000000000  132,15   123,6  109,73  50,71
# ...            ...          ...          ...     ...     ...     ...    ...
# 2019-01-01      28  10000000000  10000000000   88,84  125,47   48,04   33,4
# 2019-01-01      67  66000000000  66000000000   69,65   86,71   64,97  33,76
# 2019-01-01      66  65000000000  65000000000   72,51   91,91   58,99  32,98
# 2019-01-01      65  64000000000  64000000000  125,33  151,52    86,8  42,09
# 2019-01-01      68  68000000000  68000000000   66,79    84,4   60,73  34,37
#
#              rice groats potatoes  ... spice_value  tea_value   ai92   ai95  \
# date                               ...
# 2021-03-31  81,14  65,37    43,83  ...   40 875,05  44 193,60   43,4  48,18
# 2021-03-31  65,98  50,66    50,86  ...   21 705,41  26 263,81  49,09  50,63
# 2021-03-31  77,01  70,49    39,78  ...   75 719,70  86 481,15  42,12  45,94
# 2021-03-31  72,69  69,96    38,12  ...   27 386,71  25 340,40  43,41  47,01
# 2021-03-31  24,65  20,25    42,23  ...   14 260,44  10 247,91  51,71  51,23
# ...           ...    ...      ...  ...         ...        ...    ...    ...
# 2019-01-01  65,57  43,56    29,38  ...    3 313,00   2 147,00  41,59  43,96
# 2019-01-01  68,42  36,96     26,1  ...    3 618,00   5 465,00  40,99  44,64
# 2019-01-01  74,34  41,06    22,67  ...   26 507,71  34 152,85  40,32  43,46
# 2019-01-01  87,82   54,9    27,91  ...    3 180,17   3 063,00  43,96  45,15
# 2019-01-01  66,73  43,63    21,34  ...    3 593,26   4 436,00   41,3  44,37
#
#              ai98     dt    ai92_value  ai95_value ai98_value    dt_value
# date
# 2021-03-31  54,85  50,18    738 049,00  438 485,91   3 182,57   66 982,78
# 2021-03-31  53,71  53,58    350 912,44  144 884,38   7 341,17   36 931,85
# 2021-03-31  49,85  48,41  1 001 103,38  559 145,81      23,55  163 207,48
# 2021-03-31  47,94  46,93    400 342,50  161 002,06   6 391,44   66 398,72
# 2021-03-31  58,18  59,31    262 623,69  157 463,67  27 128,07   10 191,43
# ...           ...    ...           ...         ...        ...         ...
# 2019-01-01  46,29  49,64    190 836,19  101 768,91   2 143,36       798,8
# 2019-01-01   47,6  45,93    194 608,50  136 163,13     791,57   39 200,50
# 2019-01-01  48,17  46,13    814 581,88  562 791,31     348,24   91 853,09
# 2019-01-01  53,85   56,1    121 139,95   84 938,00   3 955,98    1 255,10
# 2019-01-01      0  44,44    156 180,80   95 813,37          0   16 293,86
#
# [69785 rows x 78 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 69785 entries, 2021-03-31 to 2019-01-01
# Data columns (total 78 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   region                    69785 non-null  int64
#  1   oktmo                     69785 non-null  int64
#  2   okato                     69785 non-null  int64
#  3   pasta                     69785 non-null  object
#  4   legumes                   69785 non-null  object
#  5   bread                     69785 non-null  object
#  6   flour                     69785 non-null  object
#  7   rice                      69785 non-null  object
#  8   groats                    69785 non-null  object
#  9   potatoes                  69785 non-null  object
#  10  сucumbers_tomatoes        69785 non-null  object
#  11  vegetables                69785 non-null  object
#  12  roots                     69785 non-null  object
#  13  сabbage                   69785 non-null  object
#  14  fruit                     69785 non-null  object
#  15  sugar                     69785 non-null  object
#  16  candy                     69785 non-null  object
#  17  biscuits                  69785 non-null  object
#  18  mutton                    69785 non-null  object
#  19  beef                      69785 non-null  object
#  20  chicken                   69785 non-null  object
#  21  pork                      69785 non-null  object
#  22  fish                      69785 non-null  object
#  23  herring                   69785 non-null  object
#  24  curd                      69785 non-null  object
#  25  sour_creame               69785 non-null  object
#  26  butter                    69785 non-null  object
#  27  milk_kefir                69785 non-null  object
#  28  cheese                    69785 non-null  object
#  29  egg                       69785 non-null  object
#  30  margarine                 69785 non-null  object
#  31  oil                       69785 non-null  object
#  32  salt                      69785 non-null  object
#  33  spice                     69785 non-null  object
#  34  tea                       69785 non-null  object
#  35  cpi_1                     69785 non-null  object
#  36  cpi_2                     69785 non-null  object
#  37  cpi_3                     69785 non-null  object
#  38  pasta_value               69785 non-null  object
#  39  legumes_value             69785 non-null  object
#  40  bread_value               69785 non-null  object
#  41  flour_value               69785 non-null  object
#  42  rice_value                69785 non-null  object
#  43  groats_value              69785 non-null  object
#  44  potatoes_value            69785 non-null  object
#  45  сucumbers_tomatoes_value  69785 non-null  object
#  46  vegetables_value          69785 non-null  object
#  47  roots_value               69785 non-null  object
#  48  сabbage_value             69785 non-null  object
#  49  fruit_value               69785 non-null  object
#  50  sugar_value               69785 non-null  object
#  51  candy_value               69785 non-null  object
#  52  biscuits_value            69785 non-null  object
#  53  mutton_value              69785 non-null  object
#  54  beef_value                69785 non-null  object
#  55  chicken_value             69785 non-null  object
#  56  pork_value                69785 non-null  object
#  57  fish_value                69785 non-null  object
#  58  herring_value             69785 non-null  object
#  59  curd_value                69785 non-null  object
#  60  sour_creame_value         69785 non-null  object
#  61  butter_value              69785 non-null  object
#  62  milk_kefir_value          69785 non-null  object
#  63  cheese_value              69785 non-null  object
#  64  egg_value                 69785 non-null  object
#  65  margarine_value           69785 non-null  object
#  66  oil_value                 69785 non-null  object
#  67  salt_value                69785 non-null  object
#  68  spice_value               69785 non-null  object
#  69  tea_value                 69785 non-null  object
#  70  ai92                      69785 non-null  object
#  71  ai95                      69785 non-null  object
#  72  ai98                      69785 non-null  object
#  73  dt                        69785 non-null  object
#  74  ai92_value                69785 non-null  object
#  75  ai95_value                69785 non-null  object
#  76  ai98_value                69785 non-null  object
#  77  dt_value                  69785 non-null  object
# dtypes: int64(3), object(75)
# memory usage: 42.1+ MB

# %%
# приведем данные в порядок: для преобразования нужно почистить числовые данные
data_ = data[['region', 'oktmo', 'okato']]
data.drop(['region', 'oktmo', 'okato'], axis=1, inplace=True)

columns = data.columns
for i in range(len(columns)):
    if isinstance(data[columns[i]][0], str):
        #print(columns[i])
        data[columns[i]] = data[columns[i]].str.replace(u'\xa0', ' ')
        data[columns[i]] = data[columns[i]].str.replace(' ', '')
        data[columns[i]] = data[columns[i]].str.replace(',', '.')

data = data.apply(pd.to_numeric, downcast='float', errors='ignore')
# data = data.astype(np.float16)

data = data.fillna(0)

data[['region', 'oktmo', 'okato']] = data_[['region', 'oktmo', 'okato']]
data = data.astype({'region': 'int8'})#, 'oktmo': 'int64', 'okato': 'int64'})

data
# Out:
#                  pasta     legumes       bread      flour       rice  \
# date
# 2021-03-31   86.360001  108.629997   75.099998  34.060001  81.139999
# 2021-03-31   83.480003  123.529999   73.870003  42.340000  65.980003
# 2021-03-31   75.589996  103.610001   81.430000  33.270000  77.010002
# 2021-03-31   73.769997   87.809998   76.339996  32.330002  72.690002
# 2021-03-31  132.149994  123.599998  109.730003  50.709999  24.650000
# ...                ...         ...         ...        ...        ...
# 2019-01-01   88.839996  125.470001   48.040001  33.400002  65.570000
# 2019-01-01   69.650002   86.709999   64.970001  33.759998  68.419998
# 2019-01-01   72.510002   91.910004   58.990002  32.980000  74.339996
# 2019-01-01  125.330002  151.520004   86.800003  42.090000  87.820000
# 2019-01-01   66.790001   84.400002   60.730000  34.369999  66.730003
#
#                groats   potatoes  сucumbers_tomatoes  vegetables      roots  \
# date
# 2021-03-31  65.370003  43.830002          142.830002   33.990002  65.910004
# 2021-03-31  50.660000  50.860001          189.449997   37.049999  66.510002
# 2021-03-31  70.489998  39.779999          141.619995   34.110001  67.620003
# 2021-03-31  69.959999  38.119999          130.839996   25.510000  56.509998
# 2021-03-31  20.250000  42.230000          183.080002   56.220001  56.380001
# ...               ...        ...                 ...         ...        ...
# 2019-01-01  43.560001  29.379999          187.009995   69.400002  65.279999
# 2019-01-01  36.959999  26.100000          157.639999   29.700001  32.630001
# 2019-01-01  41.060001  22.670000          165.570007   26.330000  32.480000
# 2019-01-01  54.900002  27.910000          188.380005   38.919998  53.860001
# 2019-01-01  43.630001  21.340000          156.089996   24.799999  28.299999
#
#             ...       ai95       ai98         dt    ai92_value     ai95_value  \
# date        ...
# 2021-03-31  ...  48.180000  54.849998  50.180000  7.380490e+05  438485.906250
# 2021-03-31  ...  50.630001  53.709999  53.580002  3.509124e+05  144884.375000
# 2021-03-31  ...  45.939999  49.849998  48.410000  1.001103e+06  559145.812500
# 2021-03-31  ...  47.009998  47.939999  46.930000  4.003425e+05  161002.062500
# 2021-03-31  ...  51.230000  58.180000  59.310001  2.626237e+05  157463.671875
# ...         ...        ...        ...        ...           ...            ...
# 2019-01-01  ...  43.959999  46.290001  49.639999  1.908362e+05  101768.906250
# 2019-01-01  ...  44.639999  47.599998  45.930000  1.946085e+05  136163.125000
# 2019-01-01  ...  43.459999  48.169998  46.130001  8.145819e+05  562791.312500
# 2019-01-01  ...  45.150002  53.849998  56.099998  1.211400e+05   84938.000000
# 2019-01-01  ...  44.369999   0.000000  44.439999  1.561808e+05   95813.367188
#
#               ai98_value       dt_value  region        oktmo        okato
# date
# 2021-03-31   3182.570068   66982.781250      72  71000000000  71000000000
# 2021-03-31   7341.169922   36931.851562      75  76000000000  76000000000
# 2021-03-31     23.549999  163207.484375      74  75000000000  75000000000
# 2021-03-31   6391.439941   66398.718750      73  73000000000  73000000000
# 2021-03-31  27128.070312   10191.429688      65  64000000000  64000000000
# ...                  ...            ...     ...          ...          ...
# 2019-01-01   2143.360107     798.799988      28  10000000000  10000000000
# 2019-01-01    791.570007   39200.500000      67  66000000000  66000000000
# 2019-01-01    348.239990   91853.093750      66  65000000000  65000000000
# 2019-01-01   3955.979980    1255.099976      65  64000000000  64000000000
# 2019-01-01      0.000000   16293.860352      68  68000000000  68000000000
#
# [69785 rows x 78 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 69785 entries, 2021-03-31 to 2019-01-01
# Data columns (total 78 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pasta                     69785 non-null  float32
#  1   legumes                   69785 non-null  float32
#  2   bread                     69785 non-null  float32
#  3   flour                     69785 non-null  float32
#  4   rice                      69785 non-null  float32
#  5   groats                    69785 non-null  float32
#  6   potatoes                  69785 non-null  float32
#  7   сucumbers_tomatoes        69785 non-null  float32
#  8   vegetables                69785 non-null  float32
#  9   roots                     69785 non-null  float32
#  10  сabbage                   69785 non-null  float32
#  11  fruit                     69785 non-null  float32
#  12  sugar                     69785 non-null  float32
#  13  candy                     69785 non-null  float32
#  14  biscuits                  69785 non-null  float32
#  15  mutton                    69785 non-null  float32
#  16  beef                      69785 non-null  float32
#  17  chicken                   69785 non-null  float32
#  18  pork                      69785 non-null  float32
#  19  fish                      69785 non-null  float32
#  20  herring                   69785 non-null  float32
#  21  curd                      69785 non-null  float32
#  22  sour_creame               69785 non-null  float32
#  23  butter                    69785 non-null  float32
#  24  milk_kefir                69785 non-null  float32
#  25  cheese                    69785 non-null  float32
#  26  egg                       69785 non-null  float32
#  27  margarine                 69785 non-null  float32
#  28  oil                       69785 non-null  float32
#  29  salt                      69785 non-null  float32
#  30  spice                     69785 non-null  float32
#  31  tea                       69785 non-null  float32
#  32  cpi_1                     69785 non-null  float32
#  33  cpi_2                     69785 non-null  float32
#  34  cpi_3                     69785 non-null  float32
#  35  pasta_value               69785 non-null  float32
#  36  legumes_value             69785 non-null  float32
#  37  bread_value               69785 non-null  float32
#  38  flour_value               69785 non-null  float32
#  39  rice_value                69785 non-null  float32
#  40  groats_value              69785 non-null  float32
#  41  potatoes_value            69785 non-null  float32
#  42  сucumbers_tomatoes_value  69785 non-null  float32
#  43  vegetables_value          69785 non-null  float32
#  44  roots_value               69785 non-null  float32
#  45  сabbage_value             69785 non-null  float32
#  46  fruit_value               69785 non-null  float32
#  47  sugar_value               69785 non-null  float32
#  48  candy_value               69785 non-null  float32
#  49  biscuits_value            69785 non-null  float32
#  50  mutton_value              69785 non-null  float32
#  51  beef_value                69785 non-null  float32
#  52  chicken_value             69785 non-null  float32
#  53  pork_value                69785 non-null  float32
#  54  fish_value                69785 non-null  float32
#  55  herring_value             69785 non-null  float32
#  56  curd_value                69785 non-null  float32
#  57  sour_creame_value         69785 non-null  float32
#  58  butter_value              69785 non-null  float32
#  59  milk_kefir_value          69785 non-null  float32
#  60  cheese_value              69785 non-null  float32
#  61  egg_value                 69785 non-null  float32
#  62  margarine_value           69785 non-null  float32
#  63  oil_value                 69785 non-null  float32
#  64  salt_value                69785 non-null  float32
#  65  spice_value               69785 non-null  float32
#  66  tea_value                 69785 non-null  float32
#  67  ai92                      69785 non-null  float32
#  68  ai95                      69785 non-null  float32
#  69  ai98                      69785 non-null  float32
#  70  dt                        69785 non-null  float32
#  71  ai92_value                69785 non-null  float32
#  72  ai95_value                69785 non-null  float32
#  73  ai98_value                69785 non-null  float32
#  74  dt_value                  69785 non-null  float32
#  75  region                    69785 non-null  int8
#  76  oktmo                     69785 non-null  int64
#  77  okato                     69785 non-null  int64
# dtypes: float32(75), int64(2), int8(1)
# memory usage: 21.6 MB

# %%
data_min_date = data.index.min().date()
data_max_date = data.index.max().date()
train_period = data_max_date - data_min_date
train_period = train_period.days + 1
print(f"Данные за период: с '{data_min_date}' по '{data_max_date}' ({train_period} дней)")
# Out:
# Данные за период: с '2019-01-01' по '2021-03-31' (821 дней)

# %%
# day_0 = datetime(1970, 1, 1)
# #data['date_ts'] = ((data['day'] - day_0) / timedelta(seconds=1)).astype('int64')
# data['date_ts'] = (data['day'] - day_0).dt.total_seconds().values.astype('int64')
# data['date_ts']

# %%
print("Кол-во кодов регионов:", data.region.nunique())
print("Кол-во кодов ОКТМО:", data.oktmo.nunique())
print("Кол-во кодов ОКАТО:", data.okato.nunique())
# Out:
# Кол-во кодов регионов: 84
# Кол-во кодов ОКТМО: 85
# Кол-во кодов ОКАТО: 85

# %%
# выясним почему различается кол-во кодов регионов

# %%
data['day'] = pd.to_datetime(data.index)
data['day']
# Out:
# date
# 2021-03-31   2021-03-31
# 2021-03-31   2021-03-31
# 2021-03-31   2021-03-31
# 2021-03-31   2021-03-31
# 2021-03-31   2021-03-31
#                 ...
# 2019-01-01   2019-01-01
# 2019-01-01   2019-01-01
# 2019-01-01   2019-01-01
# 2019-01-01   2019-01-01
# 2019-01-01   2019-01-01
# Name: day, Length: 69785, dtype: datetime64[ns]

# %%
data.groupby(['region'], as_index=False).agg(cnt_day = ('day', 'count')).sort_values(by='cnt_day', ascending=False)
# Out:
#     region  cnt_day
# 20      21     1642
# 54      56      821
# 62      64      821
# 61      63      821
# 60      62      821
# ..     ...      ...
# 27      29      821
# 26      28      821
# 25      27      821
# 24      26      821
# 83      92      821
#
# [84 rows x 2 columns]

# %%
data[data['region'] == 21].groupby(['oktmo'], as_index=False).agg(cnt_day = ('day', 'count'))
# Out:
#          oktmo  cnt_day
# 0   1000000000      821
# 1  97000000000      821

# %%
data[data['region'] == 21].groupby(['okato'], as_index=False).agg(cnt_day = ('day', 'count'))
# Out:
#          okato  cnt_day
# 0   1000000000      821
# 1  97000000000      821

# %%
# код региона '21' встречается при двух разных кодах ОКТМО и ОКАТО
# может это ошибка, может нет, но это значит, что в данном случае 
# код региона не подходит для однозначной идентификации региона

# %%
data_reg = data[['region', 'oktmo', 'okato', 'day']]

# %%
data_reg = data_reg.groupby(['region', 'oktmo', 'okato'], as_index=False).agg(cnt_day = ('day', 'count'))

# %%
data_reg[data_reg['oktmo'] != data_reg['okato']]
# Out:
#     region        oktmo        okato  cnt_day
# 79      83  11800000000  11100000000      821
# 80      86  71800000000  71100000000      821
# 82      89  71900000000  71140000000      821

# %%
# для идентификации региона выбираем код ОКТМО
# попробуем его уменьшить

# %%
data_reg['oktmo_small'] = data_reg['oktmo'] // 1000000000
data_reg[data_reg['oktmo'] != data_reg['oktmo_small'] * 1000000000]
# Out:
#     region        oktmo        okato  cnt_day  oktmo_small
# 79      83  11800000000  11100000000      821           11
# 80      86  71800000000  71100000000      821           71
# 82      89  71900000000  71140000000      821           71

# %%
data_reg['oktmo_small'] = data_reg['oktmo'] // 100000000
data_reg[data_reg['oktmo'] != data_reg['oktmo_small'] * 100000000]
# Out:
# Empty DataFrame
# Columns: [region, oktmo, okato, cnt_day, oktmo_small]
# Index: []

# %%
# значит код ОКТМО можно сократить, отбросив 8 нулей
# и в дальнейшем для идентификации будем использовать такой "сокращенный" ОКТМО

# %%
data_reg = data_reg.drop('cnt_day', axis=1).sort_values(by='oktmo_small')
data_reg
# Out:
#     region        oktmo        okato  oktmo_small
# 20      21   1000000000   1000000000           10
# 22      23   3000000000   3000000000           30
# 23      24   4000000000   4000000000           40
# 24      25   5000000000   5000000000           50
# 25      26   7000000000   7000000000           70
# ..     ...          ...          ...          ...
# 18      19  95000000000  95000000000          950
# 19      20  96000000000  96000000000          960
# 21      21  97000000000  97000000000          970
# 13      14  98000000000  98000000000          980
# 78      79  99000000000  99000000000          990
#
# [85 rows x 4 columns]

# %%
data_clr = data.sort_values(by=['date', 'oktmo']).drop(['region', 'okato', 'day'], axis=1)
data_clr['oktmo_small'] = data_clr['oktmo'] // 100000000
data_clr
# Out:
#                  pasta     legumes       bread      flour       rice  \
# date
# 2019-01-01   73.129997   82.089996   44.320000  29.570000  69.150002
# 2019-01-01   87.760002  104.220001   71.099998  34.919998  77.419998
# 2019-01-01   91.279999  121.459999   71.099998  32.049999  75.239998
# 2019-01-01   89.320000  136.490005   67.010002  36.810001  67.070000
# 2019-01-01   80.370003  103.279999   58.639999  33.459999  72.709999
# ...                ...         ...         ...        ...        ...
# 2021-03-31   78.779999  103.029999   71.279999  37.220001  58.320000
# 2021-03-31   69.879997   89.089996  131.699997   0.000000   0.000000
# 2021-03-31   66.930000   82.849998   54.840000  32.279999  59.400002
# 2021-03-31  121.459999  169.199997   96.470001  44.189999  84.650002
# 2021-03-31   67.529999  119.709999   85.160004  36.660000  65.330002
#
#                groats   potatoes  сucumbers_tomatoes  vegetables       roots  \
# date
# 2019-01-01  42.720001  25.110001          156.440002   27.330000   29.730000
# 2019-01-01  53.130001  30.520000          169.600006   30.420000   32.040001
# 2019-01-01  46.980000  23.490000          193.250000   23.340000   42.950001
# 2019-01-01  39.919998  28.450001          158.259995   32.099998   51.529999
# 2019-01-01  53.099998  29.680000          169.020004   26.760000   28.010000
# ...               ...        ...                 ...         ...         ...
# 2021-03-31  47.419998  46.290001          158.639999   38.200001   70.940002
# 2021-03-31   0.000000  42.910000          164.300003   35.000000   52.560001
# 2021-03-31  52.810001  35.330002          130.649994   33.160000   56.709999
# 2021-03-31  78.680000  79.449997          271.730011   59.630001  125.580002
# 2021-03-31  37.900002  53.950001          177.500000   44.450001   89.239998
#
#             ...       ai92       ai95       ai98         dt    ai92_value  \
# date        ...
# 2019-01-01  ...  40.320000  43.790001  49.849998  46.189999  1.983370e+05
# 2019-01-01  ...  42.389999  46.549999  49.799999  44.529999  1.184586e+06
# 2019-01-01  ...  40.860001  42.669998  52.419998  49.830002  3.563638e+05
# 2019-01-01  ...  41.650002  42.520000  45.040001  47.119999  3.328065e+05
# 2019-01-01  ...  42.889999  46.290001  49.900002  45.290001  3.722870e+05
# ...         ...        ...        ...        ...        ...           ...
# 2021-03-31  ...  43.360001  46.189999  51.799999  49.750000  2.090272e+05
# 2021-03-31  ...  36.660000  47.540001   0.000000  46.660000  8.026650e+03
# 2021-03-31  ...  43.919998  47.330002   0.000000  47.419998  3.097855e+05
# 2021-03-31  ...  52.520000  53.790001  55.529999  58.340000  1.334649e+05
# 2021-03-31  ...  47.700001  49.279999  50.939999  53.009998  4.107204e+04
#
#                ai95_value    ai98_value       dt_value        oktmo  \
# date
# 2019-01-01   88123.476562    476.029999   32515.740234   1000000000
# 2019-01-01  706703.000000   9205.150391  229132.078125   3000000000
# 2019-01-01  176390.234375   1706.599976   36854.578125   4000000000
# 2019-01-01  408119.968750  21762.240234     472.450012   5000000000
# 2019-01-01  164602.468750   2339.639893   48720.730469   7000000000
# ...                   ...           ...            ...          ...
# 2021-03-31  140239.546875   8346.269531    7036.790039  95000000000
# 2021-03-31    2852.370117      0.000000     558.710022  96000000000
# 2021-03-31  162966.281250      0.000000  133677.031250  97000000000
# 2021-03-31  152689.812500   3333.300049   50819.589844  98000000000
# 2021-03-31   30001.890625   3092.110107    1344.569946  99000000000
#
#             oktmo_small
# date
# 2019-01-01           10
# 2019-01-01           30
# 2019-01-01           40
# 2019-01-01           50
# 2019-01-01           70
# ...                 ...
# 2021-03-31          950
# 2021-03-31          960
# 2021-03-31          970
# 2021-03-31          980
# 2021-03-31          990
#
# [69785 rows x 77 columns]

# %%
columns_names = data_clr.drop(['oktmo', 'oktmo_small'], axis=1).columns
columns_names
# Out:
# Index(['pasta', 'legumes', 'bread', 'flour', 'rice', 'groats', 'potatoes',
#        'сucumbers_tomatoes', 'vegetables', 'roots', 'сabbage', 'fruit',
#        'sugar', 'candy', 'biscuits', 'mutton', 'beef', 'chicken', 'pork',
#        'fish', 'herring', 'curd', 'sour_creame', 'butter', 'milk_kefir',
#        'cheese', 'egg', 'margarine', 'oil', 'salt', 'spice', 'tea', 'cpi_1',
#        'cpi_2', 'cpi_3', 'pasta_value', 'legumes_value', 'bread_value',
#        'flour_value', 'rice_value', 'groats_value', 'potatoes_value',
#        'сucumbers_tomatoes_value', 'vegetables_value', 'roots_value',
#        'сabbage_value', 'fruit_value', 'sugar_value', 'candy_value',
#        'biscuits_value', 'mutton_value', 'beef_value', 'chicken_value',
#        'pork_value', 'fish_value', 'herring_value', 'curd_value',
#        'sour_creame_value', 'butter_value', 'milk_kefir_value', 'cheese_value',
#        'egg_value', 'margarine_value', 'oil_value', 'salt_value',
#        'spice_value', 'tea_value', 'ai92', 'ai95', 'ai98', 'dt', 'ai92_value',
#        'ai95_value', 'ai98_value', 'dt_value'],
#       dtype='object')

# %%
data_new = data_clr.groupby('date').agg(cnt = ('oktmo_small', 'count'))

# %%
# переформатируем исходные данные
for oktmo_num in data_reg['oktmo_small']:
    for column_name in columns_names:
        new_column_name = column_name + '_' + str(oktmo_num)
        data_new[new_column_name] = data_clr[data_clr['oktmo_small'] == oktmo_num][column_name]

# %%
data_new.drop('cnt', axis=1, inplace=True)
data_new
# Out:
#              pasta_10  legumes_10   bread_10   flour_10    rice_10  groats_10  \
# date
# 2019-01-01  73.129997   82.089996  44.320000  29.570000  69.150002  42.720001
# 2019-01-02  64.519997   73.989998  42.700001  28.700001  66.870003  42.820000
# 2019-01-03  71.110001   70.000000  43.029999  26.990000  64.250000  40.730000
# 2019-01-04  73.949997   71.940002  43.060001  26.980000  62.840000  41.009998
# 2019-01-05  66.110001   70.440002  42.990002  27.309999  62.720001  41.330002
# ...               ...         ...        ...        ...        ...        ...
# 2021-03-27  70.040001   81.459999  54.130001  33.919998  67.500000  59.750000
# 2021-03-28  72.580002   85.099998  55.419998  34.200001  75.000000  63.529999
# 2021-03-29  73.739998   81.410004  54.599998  32.529999  74.550003  62.610001
# 2021-03-30  67.510002   66.290001  55.430000  31.770000  58.380001  50.160000
# 2021-03-31  66.930000   82.849998  54.840000  32.279999  59.400002  52.810001
#
#             potatoes_10  сucumbers_tomatoes_10  vegetables_10   roots_10  ...  \
# date                                                                      ...
# 2019-01-01    25.110001             156.440002      27.330000  29.730000  ...
# 2019-01-02    24.760000             151.500000      26.889999  32.810001  ...
# 2019-01-03    23.540001             144.710007      25.840000  32.740002  ...
# 2019-01-04    23.120001             144.229996      25.480000  30.320000  ...
# 2019-01-05    22.160000             143.350006      25.950001  30.290001  ...
# ...                 ...                    ...            ...        ...  ...
# 2021-03-27    35.459999             134.029999      33.980000  62.369999  ...
# 2021-03-28    35.220001             133.699997      32.299999  59.240002  ...
# 2021-03-29    35.110001             133.029999      32.700001  57.840000  ...
# 2021-03-30    36.590000             132.619995      32.540001  57.779999  ...
# 2021-03-31    35.330002             130.649994      33.160000  56.709999  ...
#
#             spice_value_990  tea_value_990   ai92_990   ai95_990   ai98_990  \
# date
# 2019-01-01       647.000000     544.000000  41.840000  43.720001  44.200001
# 2019-01-02      2210.580078    1617.000000  41.970001  43.770000  44.200001
# 2019-01-03      2590.429932    2161.300049  42.110001  43.869999  44.520000
# 2019-01-04      3093.489990    2033.000000  42.080002  43.889999  44.650002
# 2019-01-05      3445.209961    2078.000000  42.389999  44.270000  45.250000
# ...                     ...            ...        ...        ...        ...
# 2021-03-27      4125.939941    2602.199951  47.599998  49.250000  51.439999
# 2021-03-28      3846.060059    2297.060059  47.439999  49.209999  51.480000
# 2021-03-29      3299.100098    2193.179932  47.549999  49.279999  51.070000
# 2021-03-30      3908.000000    2533.010010  47.220001  49.270000  51.419998
# 2021-03-31      3903.840088    2571.610107  47.700001  49.279999  50.939999
#
#                dt_990  ai92_value_990  ai95_value_990  ai98_value_990  \
# date
# 2019-01-01   0.000000    22559.140625    12821.379883      902.440002
# 2019-01-02  53.250000    34219.308594    22421.009766     1037.140015
# 2019-01-03  53.490002    40634.238281    25086.210938     1211.329956
# 2019-01-04  53.459999    41623.679688    26616.560547     1565.969971
# 2019-01-05  53.490002    40964.101562    24650.019531     1475.589966
# ...               ...             ...             ...             ...
# 2021-03-27  53.259998    41167.609375    31331.439453     2494.750000
# 2021-03-28  53.290001    37482.058594    31589.460938     2790.929932
# 2021-03-29  53.290001    39841.921875    29342.310547     3133.550049
# 2021-03-30  53.369999    41248.789062    31276.099609     2713.709961
# 2021-03-31  53.009998    41072.039062    30001.890625     3092.110107
#
#             dt_value_990
# date
# 2019-01-01      0.000000
# 2019-01-02    306.239990
# 2019-01-03   4894.560059
# 2019-01-04   5289.080078
# 2019-01-05   2554.100098
# ...                  ...
# 2021-03-27    920.750000
# 2021-03-28    601.820007
# 2021-03-29   1261.530029
# 2021-03-30   1223.880005
# 2021-03-31   1344.569946
#
# [821 rows x 6375 columns]

# %%
# загрузим данные для прогноза
data_test = pd.read_csv('test.csv', sep=',', index_col='date', parse_dates=['date'], dayfirst=True)
data_test
# Out:
#             region        oktmo        okato  pasta  legumes  bread  flour  \
# date
# 2021-06-30      65  64000000000  64000000000    NaN      NaN    NaN    NaN
# 2021-06-30      66  65000000000  65000000000    NaN      NaN    NaN    NaN
# 2021-06-30      64  63000000000  63000000000    NaN      NaN    NaN    NaN
# 2021-06-30      67  66000000000  66000000000    NaN      NaN    NaN    NaN
# 2021-06-30      70  69000000000  69000000000    NaN      NaN    NaN    NaN
# ...            ...          ...          ...    ...      ...    ...    ...
# 2021-04-01      43  33000000000  33000000000    NaN      NaN    NaN    NaN
# 2021-04-01      73  73000000000  73000000000    NaN      NaN    NaN    NaN
# 2021-04-01      74  75000000000  75000000000    NaN      NaN    NaN    NaN
# 2021-04-01      72  71000000000  71000000000    NaN      NaN    NaN    NaN
# 2021-04-01      75  76000000000  76000000000    NaN      NaN    NaN    NaN
#
#             rice  groats  potatoes  ...  spice_value  tea_value  ai92  ai95  \
# date                                ...
# 2021-06-30   NaN     NaN       NaN  ...          NaN        NaN   NaN   NaN
# 2021-06-30   NaN     NaN       NaN  ...          NaN        NaN   NaN   NaN
# 2021-06-30   NaN     NaN       NaN  ...          NaN        NaN   NaN   NaN
# 2021-06-30   NaN     NaN       NaN  ...          NaN        NaN   NaN   NaN
# 2021-06-30   NaN     NaN       NaN  ...          NaN        NaN   NaN   NaN
# ...          ...     ...       ...  ...          ...        ...   ...   ...
# 2021-04-01   NaN     NaN       NaN  ...          NaN        NaN   NaN   NaN
# 2021-04-01   NaN     NaN       NaN  ...          NaN        NaN   NaN   NaN
# 2021-04-01   NaN     NaN       NaN  ...          NaN        NaN   NaN   NaN
# 2021-04-01   NaN     NaN       NaN  ...          NaN        NaN   NaN   NaN
# 2021-04-01   NaN     NaN       NaN  ...          NaN        NaN   NaN   NaN
#
#             ai98  dt  ai92_value  ai95_value  ai98_value  dt_value
# date
# 2021-06-30   NaN NaN         NaN         NaN         NaN       NaN
# 2021-06-30   NaN NaN         NaN         NaN         NaN       NaN
# 2021-06-30   NaN NaN         NaN         NaN         NaN       NaN
# 2021-06-30   NaN NaN         NaN         NaN         NaN       NaN
# 2021-06-30   NaN NaN         NaN         NaN         NaN       NaN
# ...          ...  ..         ...         ...         ...       ...
# 2021-04-01   NaN NaN         NaN         NaN         NaN       NaN
# 2021-04-01   NaN NaN         NaN         NaN         NaN       NaN
# 2021-04-01   NaN NaN         NaN         NaN         NaN       NaN
# 2021-04-01   NaN NaN         NaN         NaN         NaN       NaN
# 2021-04-01   NaN NaN         NaN         NaN         NaN       NaN
#
# [7735 rows x 78 columns]

# %%
# data_sub = pd.read_csv('sample_submission.csv', sep=',', index_col='date', parse_dates=['date'], dayfirst=True)
# data_sub

# %%
data_test_min_date = data_test.index.min().date()
data_test_max_date = data_test.index.max().date()
period = data_test_max_date - data_test_min_date
period = period.days + 1
print(f"Тестовый период: с '{data_test_min_date}' по '{data_test_max_date}' ({period} дней)")
# Out:
# Тестовый период: с '2021-04-01' по '2021-06-30' (91 дней)

# %%
# теперь для обучения модели возьмем треннировочные данные полностью

# %%
plt.figure(figsize=(15,8))
plt.plot(data_new['pasta_360'], label='Train')
plt.grid(True)
plt.legend(loc='best')
plt.title('Динамика средней взвешенной цены на макароны, руб/кг (по 63 региону)')
plt.show()

# %%
dataset = data_new.to_numpy()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
dataset = scaler.fit_transform(dataset)

# %%
n_steps_in = 365
n_steps_out = period

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        # check if we are beyond the dataset
        if out_end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
X, y = split_sequences(dataset, n_steps_in, n_steps_out)

# %%
n_output = y.shape[1] * y.shape[2]
y = y.reshape((y.shape[0], n_output))
n_features = X.shape[2]

# %%
# # 1 вариант
# model = Sequential()
# model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(n_steps_in, n_features)))
# model.add(MaxPooling1D(pool_size=2))
# model.add(Flatten())
# model.add(Dense(50, activation='relu'))
# model.add(Dense(n_output))
# model.compile(optimizer='adam', loss='mse')

# # 2 вариант
# model = Sequential()
# model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_steps_in, n_features)))
# model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
# model.add(MaxPooling1D(pool_size=2))
# model.add(Flatten())
# model.add(Dense(100, activation='relu'))
# model.add(Dense(n_output))
# model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# # 3 вариант
# model = Sequential()
# model.add(Conv1D(filters=100, kernel_size=10, activation='relu', input_shape=(n_steps_in, n_features)))
# model.add(Conv1D(filters=100, kernel_size=10, activation='relu'))
# model.add(MaxPooling1D(pool_size=2))
# model.add(Conv1D(filters=100, kernel_size=10, activation='relu'))
# model.add(Conv1D(filters=100, kernel_size=10, activation='relu'))
# model.add(MaxPooling1D(pool_size=2))
# model.add(Flatten())
# model.add(Dense(100, activation='relu'))
# model.add(Dense(n_output))
# model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# # 4 вариант
# model = Sequential()
# model.add(Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=(n_steps_in, n_features)))
# model.add(MaxPooling1D(pool_size=2))
# model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
# model.add(MaxPooling1D(pool_size=2))
# model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
# model.add(MaxPooling1D(pool_size=2))
# model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
# model.add(MaxPooling1D(pool_size=2))
# model.add(Flatten())
# model.add(Dense(128, activation='relu'))
# model.add(Dense(n_output))
# model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model = Sequential()
model.add(Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=(n_steps_in, n_features)))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(n_output))
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 363, 128)          2448128
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 361, 128)          49280
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 180, 128)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 178, 64)           24640
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 176, 64)           12352
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 88, 64)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 86, 32)            6176
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 84, 32)            3104
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 42, 32)            0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 40, 16)            1552
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 38, 16)            784
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 19, 16)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 304)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               39040
# _________________________________________________________________
# dense_1 (Dense)              (None, 580125)            74836125
# =================================================================
# Total params: 77,421,181
# Trainable params: 77,421,181
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
callbacks_list = [
#     ModelCheckpoint(filepath='best_model.epoch={epoch:02d}-val_loss={val_loss:.2f}.h5',
#                     monitor='val_loss',
#                     save_best_only=True),
    EarlyStopping(monitor='mae', patience=1)
]

# %%
# %%time
# model.fit(X, y, epochs=50, verbose=0)
# model.fit(X, y, epochs=20, verbose=1, callbacks=callbacks_list)
# model.fit(X, y, epochs=30, verbose=1, callbacks=callbacks_list)
model.fit(X, y, epochs=20, verbose=1, callbacks=callbacks_list)#, batch_size=30, validation_split=0.2)
# Out:
# Epoch 1/20
# 12/12 [==============================] - 429s 21s/step - loss: 0.1703 - mae: 0.3429
# Epoch 2/20
# 12/12 [==============================] - 198s 17s/step - loss: 0.0326 - mae: 0.1356
# Epoch 3/20
# 12/12 [==============================] - 250s 22s/step - loss: 0.0213 - mae: 0.1045
# Epoch 4/20
# 12/12 [==============================] - 153s 13s/step - loss: 0.0194 - mae: 0.0994
# Epoch 5/20
# 12/12 [==============================] - 169s 15s/step - loss: 0.0188 - mae: 0.0975
# Epoch 6/20
# 12/12 [==============================] - 108s 9s/step - loss: 0.0176 - mae: 0.0936
# Epoch 7/20
# 12/12 [==============================] - 52s 4s/step - loss: 0.0153 - mae: 0.0867
# Epoch 8/20
# 12/12 [==============================] - 64s 6s/step - loss: 0.0130 - mae: 0.0793
# Epoch 9/20
# 12/12 [==============================] - 49s 4s/step - loss: 0.0119 - mae: 0.0754
# Epoch 10/20
# 12/12 [==============================] - 48s 4s/step - loss: 0.0118 - mae: 0.0758
# Epoch 11/20
# 12/12 [==============================] - 50s 4s/step - loss: 0.0105 - mae: 0.0691
# Epoch 12/20
# 12/12 [==============================] - 44s 4s/step - loss: 0.0096 - mae: 0.0652
# Epoch 13/20
# 12/12 [==============================] - 47s 4s/step - loss: 0.0093 - mae: 0.0636
# Epoch 14/20
# 12/12 [==============================] - 39s 3s/step - loss: 0.0089 - mae: 0.0623
# Epoch 15/20
# 12/12 [==============================] - 41s 3s/step - loss: 0.0090 - mae: 0.0623
# Epoch 16/20
# 12/12 [==============================] - 42s 4s/step - loss: 0.0088 - mae: 0.0614
# Epoch 17/20
# 12/12 [==============================] - 38s 3s/step - loss: 0.0089 - mae: 0.0615
# Epoch 18/20
# 12/12 [==============================] - 48s 4s/step - loss: 0.0087 - mae: 0.0608
# Epoch 19/20
# 12/12 [==============================] - 40s 3s/step - loss: 0.0085 - mae: 0.0600
# Epoch 20/20
# 12/12 [==============================] - 41s 3s/step - loss: 0.0085 - mae: 0.0597
# Wall time: 34min

# %%
x_input = dataset[-n_steps_in:, :]
x_input = x_input.reshape((1, n_steps_in, n_features))

# %%
yhat = model.predict(x_input, verbose=0)

# %%
yhat = yhat.reshape((n_steps_out, n_features))

# %%
yhat_ = scaler.inverse_transform(yhat)

# %%
index = data_test.index.unique().sort_values()
columns = data_new.columns
data_pred = pd.DataFrame(data=yhat_, index=index, columns=columns)
data_pred
# Out:
#              pasta_10  legumes_10   bread_10   flour_10    rice_10  groats_10  \
# date
# 2021-04-01  76.395012   93.174622  58.385853  35.177452  90.925865  70.134109
# 2021-04-02  75.523575   93.115128  58.592251  34.946449  91.104927  70.168724
# 2021-04-03  76.388092   94.507713  58.505260  35.229965  91.918007  69.760147
# 2021-04-04  77.156822   93.282089  58.489376  34.953938  91.248779  70.037270
# 2021-04-05  75.941162   94.793579  59.056252  35.195850  92.066521  70.822365
# ...               ...         ...        ...        ...        ...        ...
# 2021-06-26  77.567642   93.672684  62.458195  36.570026  92.933693  72.601776
# 2021-06-27  77.307526   91.890991  62.339916  36.122189  91.576126  72.619652
# 2021-06-28  76.365257   90.087730  63.014004  36.124508  89.996521  72.116768
# 2021-06-29  77.311249   91.807190  62.781227  36.215405  91.570374  73.028694
# 2021-06-30  77.126396   92.734200  62.723000  36.020596  90.628754  71.176643
#
#             potatoes_10  сucumbers_tomatoes_10  vegetables_10   roots_10  ...  \
# date                                                                      ...
# 2021-04-01    29.974825             163.684570      48.671207  54.862808  ...
# 2021-04-02    30.668560             162.427780      49.129066  55.285816  ...
# 2021-04-03    30.666504             159.332230      49.637157  54.652294  ...
# 2021-04-04    32.337723             163.240799      50.168213  55.660202  ...
# 2021-04-05    32.087807             161.882553      49.084583  55.779846  ...
# ...                 ...                    ...            ...        ...  ...
# 2021-06-26    43.809513             118.206795      38.256218  63.470581  ...
# 2021-06-27    43.709335             117.961884      39.739059  63.276733  ...
# 2021-06-28    42.971134             114.953613      38.767792  63.509361  ...
# 2021-06-29    42.547379             116.553551      38.407116  62.931576  ...
# 2021-06-30    43.058796             115.444687      38.278591  62.826157  ...
#
#             spice_value_990  tea_value_990   ai92_990   ai95_990   ai98_990  \
# date
# 2021-04-01      4464.578613    2276.585205  47.500763  49.021679  72.051231
# 2021-04-02      4596.934082    2348.369385  47.583759  49.038006  71.424698
# 2021-04-03      4413.407227    2306.117920  47.597092  49.057037  71.853851
# 2021-04-04      4690.240234    2359.078369  47.506851  49.045937  72.002777
# 2021-04-05      4425.671875    2374.691895  47.581284  49.049873  71.169571
# ...                     ...            ...        ...        ...        ...
# 2021-06-26      5119.331055    2566.875977  48.003292  49.763985  71.303253
# 2021-06-27      4905.282715    2636.996338  48.098721  49.831059  72.094872
# 2021-06-28      5096.241211    2675.557129  48.141678  49.784500  73.138199
# 2021-06-29      5098.458984    2762.219727  48.065632  49.738342  73.560799
# 2021-06-30      5237.530273    2708.569092  48.253254  49.913845  72.286606
#
#                dt_990  ai92_value_990  ai95_value_990  ai98_value_990  \
# date
# 2021-04-01  72.657326    38569.382812    26594.429688     2666.560791
# 2021-04-02  69.452789    40325.117188    24779.412109     2629.675049
# 2021-04-03  69.998177    38657.316406    25692.855469     2761.153564
# 2021-04-04  71.889793    38089.554688    25609.384766     2751.106201
# 2021-04-05  70.421600    39053.558594    26590.636719     2749.512939
# ...               ...             ...             ...             ...
# 2021-06-26  78.698799    56904.742188    42047.996094     3659.441162
# 2021-06-27  78.276970    55855.714844    42045.632812     3674.223633
# 2021-06-28  77.363983    57652.660156    41263.300781     3442.091797
# 2021-06-29  78.774780    56421.296875    42483.117188     4012.959229
# 2021-06-30  77.564568    55369.781250    42607.085938     3961.926514
#
#             dt_value_990
# date
# 2021-04-01   4451.764160
# 2021-04-02   4142.242188
# 2021-04-03   4380.328125
# 2021-04-04   4380.210938
# 2021-04-05   5098.951660
# ...                  ...
# 2021-06-26   9508.086914
# 2021-06-27  10117.723633
# 2021-06-28  10510.813477
# 2021-06-29  10072.615234
# 2021-06-30   9784.422852
#
# [91 rows x 6375 columns]

# %%
columns = ['region', 'oktmo', 'okato', 'oktmo_small']
for column_name in columns_names:
    columns.append(column_name)

# %%
data_out = pd.DataFrame(columns=columns)
data_out
# Out:
# Empty DataFrame
# Columns: [region, oktmo, okato, oktmo_small, pasta, legumes, bread, flour, rice, groats, potatoes, сucumbers_tomatoes, vegetables, roots, сabbage, fruit, sugar, candy, biscuits, mutton, beef, chicken, pork, fish, herring, curd, sour_creame, butter, milk_kefir, cheese, egg, margarine, oil, salt, spice, tea, cpi_1, cpi_2, cpi_3, pasta_value, legumes_value, bread_value, flour_value, rice_value, groats_value, potatoes_value, сucumbers_tomatoes_value, vegetables_value, roots_value, сabbage_value, fruit_value, sugar_value, candy_value, biscuits_value, mutton_value, beef_value, chicken_value, pork_value, fish_value, herring_value, curd_value, sour_creame_value, butter_value, milk_kefir_value, cheese_value, egg_value, margarine_value, oil_value, salt_value, spice_value, tea_value, ai92, ai95, ai98, dt, ai92_value, ai95_value, ai98_value, dt_value]
# Index: []
#
# [0 rows x 79 columns]

# %%
for oktmo_num in data_reg['oktmo_small']:
    okato_num = data_reg[data_reg['oktmo_small'] == oktmo_num]['okato'].values[0]
    region_num = data_reg[data_reg['oktmo_small'] == oktmo_num]['region'].values[0]

    data_1 = pd.DataFrame(columns=columns)
    for column_name in columns_names:
        new_column_name = column_name + '_' + str(oktmo_num)
        data_1[column_name] = data_pred[new_column_name]

    data_1['oktmo_small'] = oktmo_num
    data_1['oktmo'] = oktmo_num * 100000000
    data_1['okato'] = okato_num
    data_1['region'] = region_num
    
    data_out = pd.concat([data_out, data_1])

data_out.index.name='date'
data_out = data_out.sort_values(by=['date', 'oktmo'])
data_out
# Out:
#            region        oktmo        okato oktmo_small       pasta  \
# date
# 2021-04-01     21   1000000000   1000000000          10   76.395012
# 2021-04-01     23   3000000000   3000000000          30   91.435013
# 2021-04-01     24   4000000000   4000000000          40  101.314133
# 2021-04-01     25   5000000000   5000000000          50  100.932991
# 2021-04-01     26   7000000000   7000000000          70   90.603020
# ...           ...          ...          ...         ...         ...
# 2021-06-30     19  95000000000  95000000000         950   84.084526
# 2021-06-30     20  96000000000  96000000000         960  121.003349
# 2021-06-30     21  97000000000  97000000000         970   78.510284
# 2021-06-30     14  98000000000  98000000000         980  119.525993
# 2021-06-30     79  99000000000  99000000000         990   78.690315
#
#                legumes       bread      flour        rice     groats  ...  \
# date                                                                  ...
# 2021-04-01   93.174622   58.385853  35.177452   90.925865  70.134109  ...
# 2021-04-01  129.993607   79.532417  38.954350   85.966820  72.808357  ...
# 2021-04-01  130.205658   81.355865  38.210167   95.193192  67.539116  ...
# 2021-04-01  153.469803   89.557678  45.152351   81.111679  77.352280  ...
# 2021-04-01  123.383087   73.485794  40.128616   88.490532  77.562347  ...
# ...                ...         ...        ...         ...        ...  ...
# 2021-06-30  126.515572   76.243973  37.342686   85.071327  50.341572  ...
# 2021-06-30   21.295757  180.882172  -0.213835    2.116436  77.380440  ...
# 2021-06-30   93.180779   62.610210  36.022739   91.253006  72.794273  ...
# 2021-06-30  159.032318   94.486404  50.330376  101.443016  83.673904  ...
# 2021-06-30  128.682587   90.945702  55.999187  103.223549  61.481224  ...
#
#               spice_value      tea_value       ai92       ai95       ai98  \
# date
# 2021-04-01   23515.468750   22415.878906  41.498943  45.359119   5.226919
# 2021-04-01  129053.945312  106638.281250  42.704536  48.451145  51.293655
# 2021-04-01   90866.546875   51755.933594  42.187241  44.795143  54.214294
# 2021-04-01   56989.117188   36984.054688  47.822239  47.759609  50.730392
# 2021-04-01   40877.328125   37568.242188  43.849564  48.293964  77.469193
# ...                   ...            ...        ...        ...        ...
# 2021-06-30   20167.316406   10042.668945  42.385830  45.719891  50.867207
# 2021-06-30     770.500549     844.673767  47.893436  71.747025  53.968880
# 2021-06-30   29541.947266   25016.716797  43.801743  47.404465  -0.350281
# 2021-06-30   20169.314453   12017.874023  53.885277  54.261284  56.908161
# 2021-06-30    5237.530273    2708.569092  48.253254  49.913845  72.286606
#
#                    dt    ai92_value    ai95_value    ai98_value       dt_value
# date
# 2021-04-01  47.080250  3.698551e+05  1.646374e+05    -38.728188  146929.250000
# 2021-04-01  45.831032  2.183393e+06  1.323326e+06   2823.682617  695792.937500
# 2021-04-01  53.406891  5.324671e+05  4.306425e+05  11971.645508  110965.500000
# 2021-04-01  51.813694  7.237215e+05  1.007783e+06  95688.132812  165065.671875
# 2021-04-01  47.097187  6.885279e+05  3.661223e+05    236.880646  169395.125000
# ...               ...           ...           ...           ...            ...
# 2021-06-30  50.433544  3.044381e+05  2.192138e+05  15053.112305   49278.425781
# 2021-06-30  70.433815  1.104417e+04  6.430531e+03    595.770630    1639.073853
# 2021-06-30  47.431595  4.788843e+05  2.566941e+05     -2.681412  190081.578125
# 2021-06-30  60.277420  1.817143e+05  1.853035e+05   3744.038818   52871.390625
# 2021-06-30  77.564568  5.536978e+04  4.260709e+04   3961.926514    9784.422852
#
# [7735 rows x 79 columns]

# %%
plt.figure(figsize=(15,8))
plt.plot(data_new['pasta_360'], label='Train')
plt.plot(data_out[data_out['oktmo_small'] == 360]['pasta'], label='Prediction')
plt.grid(True)
plt.legend(loc='best')
plt.title('Динамика средней взвешенной цены на макароны, руб/кг (по 63 региону)')
plt.show()

# %%
data_out.drop('oktmo_small', axis=1, inplace=True)

# %%
data_out.insert(3, 'date', data_out.index.strftime('%d.%m.%Y'))

# %%
data_out.columns
# Out:
# Index(['region', 'oktmo', 'okato', 'date', 'pasta', 'legumes', 'bread',
#        'flour', 'rice', 'groats', 'potatoes', 'сucumbers_tomatoes',
#        'vegetables', 'roots', 'сabbage', 'fruit', 'sugar', 'candy', 'biscuits',
#        'mutton', 'beef', 'chicken', 'pork', 'fish', 'herring', 'curd',
#        'sour_creame', 'butter', 'milk_kefir', 'cheese', 'egg', 'margarine',
#        'oil', 'salt', 'spice', 'tea', 'cpi_1', 'cpi_2', 'cpi_3', 'pasta_value',
#        'legumes_value', 'bread_value', 'flour_value', 'rice_value',
#        'groats_value', 'potatoes_value', 'сucumbers_tomatoes_value',
#        'vegetables_value', 'roots_value', 'сabbage_value', 'fruit_value',
#        'sugar_value', 'candy_value', 'biscuits_value', 'mutton_value',
#        'beef_value', 'chicken_value', 'pork_value', 'fish_value',
#        'herring_value', 'curd_value', 'sour_creame_value', 'butter_value',
#        'milk_kefir_value', 'cheese_value', 'egg_value', 'margarine_value',
#        'oil_value', 'salt_value', 'spice_value', 'tea_value', 'ai92', 'ai95',
#        'ai98', 'dt', 'ai92_value', 'ai95_value', 'ai98_value', 'dt_value'],
#       dtype='object')

# %%
data_out.to_csv('submission.csv', index=False, sep=',')
